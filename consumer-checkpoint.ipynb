# %%
from kafka import KafkaConsumer
import requests
from kafka import TopicPartition

# %%
topic = TopicPartition('raw_tweets', 0)
consumer = KafkaConsumer(bootstrap_servers = '192.168.99.100:29092')

consumer.assign([topic])

for msg in consumer: print (msg)
# Out:
# ConsumerRecord(topic='raw_tweets', partition=0, offset=110849, timestamp=1530872664634, timestamp_type=0, key=None, value=b'0    Mon Apr 06 22:20:09 PDT 2009\n1                        NO_QUERY\n2                         mimismo\n3       @twittera que me muera ? ', checksum=None, serialized_key_size=-1, serialized_value_size=135)
# ConsumerRecord(topic='raw_tweets', partition=0, offset=110850, timestamp=1530872667639, timestamp_type=0, key=None, value=b"0                   Mon Apr 06 22:20:16 PDT 2009\n1                                       NO_QUERY\n2                                 erinx3leannexo\n3    spring break in plain city... it's snowing ", checksum=None, serialized_key_size=-1, serialized_value_size=195)
# ...
